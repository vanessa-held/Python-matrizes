# %%
# 'soma'
def  somar ( m1 , m2 ):
    matriz_soma  = []
    # Supondo que as duas matrizes possuem o mesmo tamanho
    quant_linhas  =  len ( m1 ) # Conta linhas linhas existem
    quant_colunas  =  len ( m1 [ 0 ]) # Conta quantos elementos têm em uma linha
    para  i  no  intervalo ( quant_linhas ):
        # Cria uma nova linha na matriz_soma
        matriz_soma . anexar ([])
        para  j  no  intervalo ( quant_colunas ):
            # Somando os elementos que possuem o mesmo índice
            soma  =  m1 [ i ] [ j ] +  m2 [ i ] [ j ]
            matriz_soma [ i ]. anexar ( soma )
    retornar  matriz_soma

def  mult_escalar ( matriz , escalar ):
    matriz_mult  = []
    quant_linhas  =  len ( matriz ) # Conta linhas linhas existem
    quant_colunas  =  len ( matriz [ 0 ]) # Conta quantos elementos têm em uma linha
    para  i  no  intervalo ( quant_linhas ):
        # Cria uma nova linha na matriz_mult
        matriz_mult . anexar ([])
        para  j  no  intervalo ( quant_colunas ):
            # Multiplicando cada elemento pelo escalar
            mult  =  escalar  *  matriz [ i ] [ j ]
            matriz_mult [ i ]. anexar ( mult )
    return  matriz_mult


# multiplicação entre matrizes
def  matriz_mult ( a , b ):
    linhaA , colunaA  =  len ( a ), len ( a [ 0 ])
    linhaB , colunaB  =  len ( b ), len ( b [ 0 ])
    if  colunaA  ! =  linhaB :
        print ( f "Não é possível calcular a multiplicação. Matriz A tem { colunaA } colunas, matriz B tem { linhaB } linhas" )
        return []

    r  = []
    para  i  no  intervalo ( linhaA ):
        r . append ([ 0 ] *  colunaB )   # Adiciona uma linha nova e gera todas as colunas dessa linha
        para  j  no  intervalo ( colunaB ):
            for  k  in  range ( colunaA ):   # pode usar também linhaB, já que nesse ponto elas são iguais
                r [ i ] [ j ] + =  a [ i ] [ k ] *  b [ k ] [ j ]
    voltar  r


def  matriz_nula ( nlinhas , ncols ):
    M  = []
    para  i  no  alcance ( nlinhas ):
        linha  = [ 0 ] * ncols
        M . anexar ( linha )
    retornar  M

def  transposta ( M ):
    nlinhas  =  len ( M )   # Conta linhas linhas existem
    ncolunas  =  len ( M [ 0 ])   # Conta quantos elementos têm em uma linha
    T  =  matriz_nula ( ncolunas , nlinhas )
    para  i  no  alcance ( nlinhas ):
        para  j  no  intervalo ( ncolunas ):
            T [ j ] [ i ] =  M [ i ] [ j ]
    retornar  T


#matriz inversa
def  determinante_matriz2 ( m ):
    retornar  m [ 0 ] [ 0 ] * m [ 1 ] [ 1 ] -  m [ 0 ] [ 1 ] * m [ 1 ] [ 0 ]
    
def  matriz_inversa2 ( m ):
    det  =  determinante_matriz2 ( m )
    se  det  ==  0 :
        print ( "Determinar igual a zero" )
        return []
    a  =  1 / det
    b  =  mult_escalar ( matrix_tamplate ( m ), a )
   
    voltar  b

def  matrix_tamplate ( m ): #cria o formato da matriz
    resultado  = [[ 0 , 0 ], [ 0 , 0 ]]
    resultado [ 0 ] [ 0 ] =  m [ 1 ] [ 1 ]
    resultado [ 0 ] [ 1 ] =  -  m [ 0 ] [ 1 ]
    resultado [ 1 ] [ 0 ] =  -  m [ 1 ] [ 0 ]
    resultado [ 1 ] [ 1 ] =  m [ 0 ] [ 0 ]

    retorno  resultado



# função de subtração entre duas matrizes
def  subtrair ( a , b ):
    return  somar ( a , mult_escalar ( b , - 1 ))
# Out:
#   File "<ipython-input-1-0a3f1b93cdcb>", line 7
#     para  i  no  intervalo ( quant_linhas ):
#           ^
# SyntaxError: invalid syntax

# %%
if  __name__  ==  '__main__' :

    Matriz_A  = [[ 2 , 1 ], [ - 3 , 4 ]]
    Matriz_B  = [[ 0 , - 1 ], [ 2 , 5 ]]
    Matriz_C  = [[ 3 , 0 ], [ 6 , 1 ]]

  
    #Resposta questão 1 #
    imprimir ( f "Resultado questão 1: \ n  { matriz_mult ( Matriz_A , Matriz_B ) } \ n " )
    
    #Resposta 2 (A + b) + (4 * c) #
    r2  =  somar ( somar ( Matriz_A , Matriz_B ), mult_escalar ( Matriz_C , 4 ))
    imprimir ( f "Resultado questão 2: \ n  { r2 } \ n " )

    #Resposta 3 [A + (B-Ct]) * B-1] #
    r3  =  subtrair ( Matriz_B , transposta ( Matriz_C ))
    r3  =  somar ( Matriz_A , r3 )
    r3  =  matriz_mult ( r3 , matriz_inversa2 ( Matriz_B ))
    imprimir ( f "Resultado questão 3: \ n  { r3 } \ n " )
  

    #Resposta 4 (A * A-1) = Em #
    r4  =  matriz_mult ( Matriz_A , matriz_inversa2 ( Matriz_A ))
    imprimir ( f "Resultado questão 4: \ n  { r4 } \ n " )
    imprimir ( f 'Resultado Matriz inversa: \ n { matriz_inversa2 ( Matriz_A ) } ' )

    #Resposta (b + At * C-1 -Bt) = Em #
    r5  =  matriz_mult ( transposta ( Matriz_A ), matriz_inversa2 ( Matriz_C )) # Em * C-1
    r5  =  somar ( Matriz_B , r5 )
    r5  =  subtrair ( r5 , transposta ( Matriz_B ))
    imprimir ( f "Resultado questão 5: \ n  { r5 } \ n " )
